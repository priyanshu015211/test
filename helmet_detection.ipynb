# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshu015211/test/blob/main/helmet_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hkZ0p5eTFeT4T0UAMHjQ")
project = rf.workspace("vishals-workspace-imhua").project("my-first-project-uwlgs")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 79.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 128.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-1 in yolov8:: 100%|██████████| 2152/2152 [00:00<00:00, 6502.71it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")

model.train(
    data="My-First-Project-1/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.52 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.predict(
    source="My-First-Project-1/test/images",
    save=True,
    conf=0.25
)
# Out:
# image 1/63 /content/My-First-Project-1/test/images/BikesHelmets103_png.rf.57c253aa091af692ed9a9c2da1212a9f.jpg: 640x640 (no detections), 36.1ms
# image 2/63 /content/My-First-Project-1/test/images/BikesHelmets129_png.rf.6fdaa0c269e9fa08af4ce59c0f2e9706.jpg: 640x640 1 With Helmet, 36.1ms
# image 3/63 /content/My-First-Project-1/test/images/BikesHelmets133_png.rf.3959e3294093d1e59e5e92d45e73e7cd.jpg: 640x640 4 Without Helmets, 36.1ms
# image 4/63 /content/My-First-Project-1/test/images/BikesHelmets136_png.rf.ff2c1e376f4095100f82cf9f0129cac9.jpg: 640x640 1 With Helmet, 33.2ms
# image 5/63 /content/My-First-Project-1/test/images/BikesHelmets146_png.rf.69bf83c959b090f141fd5901997c227e.jpg: 640x640 5 With Helmets, 33.3ms
# image 6/63 /content/My-First-Project-1/test/images/BikesHelmets152_png.rf.1184242b23c7c5c8783867993afbcfff.jpg: 640x640 6 With Helmets, 32.6ms
# ...

# %%
model.val()
# Out:
# Ultralytics 8.4.52 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1350.1±1056.1 MB/s, size: 59.0 KB)
# val: Scanning /content/My-First-Project-1/valid/labels.cache... 125 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 125/125 32.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.2it/s 6.7s
#                    all        125        228      0.824      0.733       0.83      0.489
#            With Helmet         90        151      0.865      0.808      0.895      0.553
#         Without Helmet         40         77      0.784      0.659      0.765      0.424
# Speed: 6.2ms preprocess, 21.5ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to /content/runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
from IPython.display import Image, display
display(Image('/content/runs/detect/predict/BikesHelmets210_png.rf.4cf53c0cd75cbad13e414a5f661ad6f0.jpg'))

# %%
from IPython.display import Image, display
display(Image('/content/runs/detect/predict/BikesHelmets381_png.rf.94548ac901ce93f466b120803f1a6675.jpg'))

# %%
from IPython.display import Image, display
display(Image('/content/runs/detect/predict/BikesHelmets146_png.rf.69bf83c959b090f141fd5901997c227e.jpg'))

# %%
from IPython.display import Image, display
display(Image('/content/runs/detect/predict/BikesHelmets303_png.rf.3df623e68c929135fe918cf30589f595.jpg'))

# %%
from IPython.display import Image, display
display(Image('/content/runs/detect/predict/BikesHelmets353_png.rf.0936ec424edc1e1aac59589cd61806c1.jpg'))

# %%
from IPython.display import Image, display
display(Image('/content/runs/detect/predict/BikesHelmets550_png.rf.cf539c8fd810d411c38f4085ddf81cf6.jpg'))
